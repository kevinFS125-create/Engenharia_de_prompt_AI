# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinFS125-create/Engenharia_de_prompt_AI/blob/main/Aula07_Programa%C3%A7%C3%A3o_assistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assistida Nome: Kevin Ferreira da Silva (Turma de Sexta)

# %%
numeros=[1,2,3]
soma=0
i=0
while i<len(numeros):
  soma+=numeros[i]
  i+=1

print(soma)
# Out:
# 6

# %%
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
